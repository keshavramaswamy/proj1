# %%
# %matplotlib inline
from bs4 import BeautifulSoup
import requests
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
df_test = pd.read_csv('./test.csv',index_col=0)

# %%
df_sales_history = pd.read_csv('./df_sales_history.csv')

# %%
df_sales_history.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  2013-01-02               0       59    22154       999.0           1.0
# 1  2013-01-23               0       24    22154       999.0           1.0
# 2  2013-01-20               0       27    22154       999.0           1.0
# 3  2013-01-02               0       25    22154       999.0           1.0
# 4  2013-01-03               0       25    22154       999.0           1.0
#
#    item_category_id  month  day    yr month_year
# 0                37      1    2  2013     1_2013
# 1                37      1   23  2013     1_2013
# 2                37      1   20  2013     1_2013
# 3                37      1    2  2013     1_2013
# 4                37      1    3  2013     1_2013

# %%
df_test.head()
# Out:
#     shop_id  item_id
# ID
# 0         5     5037
# 1         5     5320
# 2         5     5233
# 3         5     5232
# 4         5     5268

# %%
df1 = df_sales_history.copy()

# %%
df_test.head()
# Out:
#     shop_id  item_id
# ID
# 0         5     5037
# 1         5     5320
# 2         5     5233
# 3         5     5232
# 4         5     5268

# %%
df1['shop_item'] = [str(row.shop_id) + '_' + str(row.item_id) for i, row in df1.iterrows()]

# %%
df1.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  2013-01-02               0       59    22154       999.0           1.0
# 1  2013-01-23               0       24    22154       999.0           1.0
# 2  2013-01-20               0       27    22154       999.0           1.0
# 3  2013-01-02               0       25    22154       999.0           1.0
# 4  2013-01-03               0       25    22154       999.0           1.0
#
#    item_category_id  month  day    yr month_year shop_item
# 0                37      1    2  2013     1_2013  59_22154
# 1                37      1   23  2013     1_2013  24_22154
# 2                37      1   20  2013     1_2013  27_22154
# 3                37      1    2  2013     1_2013  25_22154
# 4                37      1    3  2013     1_2013  25_22154

# %%
df_test['shop_item'] = [str(row.shop_id) + '_' + str(row.item_id) for i, row in df_test.iterrows()]

# %%
df_test.head()
# Out:
#     shop_id  item_id shop_item
# ID
# 0         5     5037    5_5037
# 1         5     5320    5_5320
# 2         5     5233    5_5233
# 3         5     5232    5_5232
# 4         5     5268    5_5268

# %%
df1.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  2013-01-02               0       59    22154       999.0           1.0
# 1  2013-01-23               0       24    22154       999.0           1.0
# 2  2013-01-20               0       27    22154       999.0           1.0
# 3  2013-01-02               0       25    22154       999.0           1.0
# 4  2013-01-03               0       25    22154       999.0           1.0
#
#    item_category_id  month  day    yr month_year shop_item
# 0                37      1    2  2013     1_2013  59_22154
# 1                37      1   23  2013     1_2013  24_22154
# 2                37      1   20  2013     1_2013  27_22154
# 3                37      1    2  2013     1_2013  25_22154
# 4                37      1    3  2013     1_2013  25_22154

# %%
df_test.shape
# Out:
# (214200, 3)

# %%
len(df_test.shop_item.unique())
# Out:
# 214200

# %%
len(df1.shop_item.unique())
# Out:
# 424124

# %%
df1.shape
# Out:
# (2935849, 12)

# %%
df1.set_index('shop_item',inplace=True)

# %%
df1.index
# Out:
# Index([u'59_22154', u'24_22154', u'27_22154', u'25_22154', u'25_22154',
#        u'25_22154', u'25_22154', u'25_22154', u'6_22154', u'15_22154',
#        ...
#        u'25_13476', u'25_13280', u'25_16105', u'25_16094', u'25_14709',
#        u'25_8428', u'25_7903', u'25_7610', u'25_7635', u'25_7640'],
#       dtype='object', name=u'shop_item', length=2935849)

# %%
df1.loc['25_22154']
# Out:
#                  date  date_block_num  shop_id  item_id  item_price  \
# shop_item
# 25_22154   2013-01-02               0       25    22154       999.0
# 25_22154   2013-01-03               0       25    22154       999.0
# 25_22154   2013-01-20               0       25    22154       999.0
# 25_22154   2013-01-23               0       25    22154       999.0
# 25_22154   2013-01-26               0       25    22154       999.0
# 25_22154   2015-08-27              31       25    22154       299.0
# 25_22154   2015-09-02              32       25    22154       299.0
#
#            item_cnt_day  item_category_id  month  day    yr month_year
# shop_item
# 25_22154            1.0                37      1    2  2013     1_2013
# 25_22154            1.0                37      1    3  2013     1_2013
# 25_22154            1.0                37      1   20  2013     1_2013
# 25_22154            1.0                37      1   23  2013     1_2013
# ...

# %%
df1.head()
# Out:
#                  date  date_block_num  shop_id  item_id  item_price  \
# shop_item
# 59_22154   2013-01-02               0       59    22154       999.0
# 24_22154   2013-01-23               0       24    22154       999.0
# 27_22154   2013-01-20               0       27    22154       999.0
# 25_22154   2013-01-02               0       25    22154       999.0
# 25_22154   2013-01-03               0       25    22154       999.0
#
#            item_cnt_day  item_category_id  month  day    yr month_year
# shop_item
# 59_22154            1.0                37      1    2  2013     1_2013
# 24_22154            1.0                37      1   23  2013     1_2013
# 27_22154            1.0                37      1   20  2013     1_2013
# 25_22154            1.0                37      1    2  2013     1_2013
# 25_22154            1.0                37      1    3  2013     1_2013

# %%
df1[(df1.month_year=='12_2012')].day.max()
# Out:
# nan

# %%
print len(df1[df1.yr == 2013]) / 12.
print len(df1[df1.yr == 2014]) / 12.
print len(df1[df1.yr == 2015]) / 10.
# Out:
# 105630.166667
# 87988.4166667
# 61242.6

# %%
df_train_feat = df1[df1.month_year!='10_2015']

# %%
df_train_feat.shape
# Out:
# (2882335, 11)

# %%
df1.shape
# Out:
# (2935849, 11)

# %%
df1_train_success = df1[df1.month_year=='10_2015']

# %%
len(df1_train_success.index.unique())
# Out:
# 31531

# %%
df_train_feat.plot.scatter(x='item_price',y='item_cnt_day')

# %%
df_train_feat.head()
# Out:
#                  date  date_block_num  shop_id  item_id  item_price  \
# shop_item
# 59_22154   2013-01-02               0       59    22154       999.0
# 24_22154   2013-01-23               0       24    22154       999.0
# 27_22154   2013-01-20               0       27    22154       999.0
# 25_22154   2013-01-02               0       25    22154       999.0
# 25_22154   2013-01-03               0       25    22154       999.0
#
#            item_cnt_day  item_category_id  month  day    yr month_year
# shop_item
# 59_22154            1.0                37      1    2  2013     1_2013
# 24_22154            1.0                37      1   23  2013     1_2013
# 27_22154            1.0                37      1   20  2013     1_2013
# 25_22154            1.0                37      1    2  2013     1_2013
# 25_22154            1.0                37      1    3  2013     1_2013

# %%
df1.columns
# Out:
# Index([u'date', u'date_block_num', u'shop_id', u'item_id', u'item_price',
#        u'item_cnt_day', u'item_category_id', u'month', u'day', u'yr',
#        u'month_year'],
#       dtype='object')

# %%
df1.reset_index(inplace=True)
df1.set_index(['shop_item','date_block_num'],inplace=True)

# %%
df1.head(20)
# Out:
#                                 date  shop_id  item_id  item_price  \
# shop_item date_block_num
# 59_22154  0               2013-01-02       59    22154       999.0
# 24_22154  0               2013-01-23       24    22154       999.0
# 27_22154  0               2013-01-20       27    22154       999.0
# 25_22154  0               2013-01-02       25    22154       999.0
#           0               2013-01-03       25    22154       999.0
#           0               2013-01-20       25    22154       999.0
#           0               2013-01-23       25    22154       999.0
#           0               2013-01-26       25    22154       999.0
# 6_22154   0               2013-01-27        6    22154       999.0
# 15_22154  0               2013-01-10       15    22154       999.0
# 7_22154   0               2013-01-10        7    22154       999.0
# 31_22154  0               2013-01-05       31    22154       999.0
# 54_22154  0               2013-01-02       54    22154       999.0
# ...

# %%
df2 = df1.groupby(['shop_item','date_block_num'])[['item_price','item_cnt_day']].sum()

# %%
df2.head()
# Out:
#                           item_price  item_cnt_day
# shop_item date_block_num
# 0_1000    0                    290.0           5.0
#           1                    232.0           4.0
# 0_10004   1                     64.0           1.0
# 0_1001    0                    116.0           2.0
# 0_10012   0                     76.0           1.0

# %%
df2.columns = ['total_sales','item_cnt_month']

# %%
df2.head()
# Out:
#                           total_sales  item_cnt_month
# shop_item date_block_num
# 0_1000    0                     290.0             5.0
#           1                     232.0             4.0
# 0_10004   1                      64.0             1.0
# 0_1001    0                     116.0             2.0
# 0_10012   0                      76.0             1.0

# %%
next(df2.iterrows())[0][0].split('_')
# Out:
# ['0', '1000']

# %%
df2['shop'] = [int(i[0].split('_')[0]) for i, _ in df2.iterrows()]
#df2['item'] = [i[0].sp1it('_')[1] for i, _ in df2.iterrows()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-70adc4c43d92> in <module>()
#       1 df2['shop'] = [i[0].split('_')[0] for i, _ in df2.iterrows()]
# ----> 2 df2['item'] = [i[0].sp1it('_')[1] for i, _ in df2.iterrows()]
#
# AttributeError: 'str' object has no attribute 'sp1it'

# %%
int('1000')
# Out:
# 1000

# %%
for i, _ in df2.iterrows():
    print i[0].split('_')[1]
# Out:
# 1000
# 1000
# 10004
# 1001
# 10012
# 10012
# 1002
# 1003
# 10033
# 10038
# 10039
# 10039
# 1004
# 10048
# 1005
# 10051
# 10051
# 10063
# 10064
# 10064
# 10080
# 10081
# 10086
# 10086
# 10088
# 10089
# 10097
# 10106
# 10106
# 10107
# 10107
# 10110
# 10110
# 10111
# 10127
# 10128
# 10129
# 1013
# 10133
# 10140
# 10141
# 10146
# 1015
# 10159
# 1016
# 1016
# 10163
# 10164
# 1017
# 10171
# 10171
# 10172
# 10173
# 10178
# 1018
# 10183
# 10184
# 10193
# 1022
# 10225
# 10230
# 10230
# 10242
# 1025
# 10269
# 10269
# 1027
# 10270
# 10270
# 10272
# 10274
# 10275
# 10285
# 10286
# 1029
# 10308
# 10308
# 10309
# 10309
# 1031
# 1032
# 10323
# 10326
# 10327
# 10329
# 10330
# 10331
# 10331
# 10334
# 10337
# 10340
# 10340
# 10343
# 10343
# 10348
# 1035
# 10355
# 10355
# 10358
# 10359
# 10359
# 1036
# 10370
# 10373
# 10387
# 10387
# 10389
# 10389
# 10390
# 10390
# 10394
# 10394
# 10401
# 10413
# 10415
# 10421
# 10421
# 10426
# 10426
# 10434
# 10440
# 10450
# 10451
# 10452
# 10452
# 10459
# 10466
# ...

# %%
df2['item'] = [i[0].split('_')[1] for i, _ in df2.iterrows()]

# %%
df2.head()
# Out:
#                           total_sales  item_cnt_month shop   item
# shop_item date_block_num
# 0_1000    0                     290.0             5.0    0   1000
#           1                     232.0             4.0    0   1000
# 0_10004   1                      64.0             1.0    0  10004
# 0_1001    0                     116.0             2.0    0   1001
# 0_10012   0                      76.0             1.0    0  10012

# %%
item_df = pd.read_csv('items.csv',index_col=0)

# %%
item_df.head()
# Out:
#                                                     item_id  item_category_id
# item_name
# ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D                 0                40
# !ABBYY FineReader 12 Professional Edition Full ...        1                76
# ***В ЛУЧАХ СЛАВЫ   (UNV)                    D             2                40
# ***ГОЛУБАЯ ВОЛНА  (Univ)                      D           3                40
# ***КОРОБКА (СТЕКЛО)                       D               4                40

# %%
item_df[item_df.item_id == 1000]
# Out:
#                                   item_id  item_category_id
# item_name
# 3D Action Puzzle "Зомби" Уборщик     1000                67

# %%
df2.shop = [int(i) for i in df2.shop]
df2.item = [int(i) for i in df2.item]

# %%
df3 = pd.merge(df2,item_df,left_on='item',right_on='item_id')

# %%
df2.shape
# Out:
# (1609124, 4)

# %%
df3.index = df2.index

# %%
df3.head()
# Out:
#                           total_sales  item_cnt_month  shop  item  item_id  \
# shop_item date_block_num
# 0_1000    0                     290.0             5.0     0  1000     1000
#           1                     232.0             4.0     0  1000     1000
# 0_10004   1                      58.0             1.0    10  1000     1000
# 0_1001    0                      58.0             1.0    10  1000     1000
# 0_10012   0                      58.0             1.0    10  1000     1000
#
#                           item_category_id
# shop_item date_block_num
# 0_1000    0                             67
#           1                             67
# 0_10004   1                             67
# 0_1001    0                             67
# 0_10012   0                             67

# %%
df3.drop('item_id',inplace=True,axis=1)
df3.rename(columns={'item_category_id':'category'},inplace=True)

# %%
df3.head()
# Out:
#                           total_sales  item_cnt_month  shop  item  category
# shop_item date_block_num
# 0_1000    0                     290.0             5.0     0  1000        67
#           1                     232.0             4.0     0  1000        67
# 0_10004   1                      58.0             1.0    10  1000        67
# 0_1001    0                      58.0             1.0    10  1000        67
# 0_10012   0                      58.0             1.0    10  1000        67

# %%
df_test.head()
# Out:
#     shop_id  item_id shop_item
# ID
# 0         5     5037    5_5037
# 1         5     5320    5_5320
# 2         5     5233    5_5233
# 3         5     5232    5_5232
# 4         5     5268    5_5268

# %%
df1.reset_index(inplace=True)

# %%
df1.head()
# Out:
#   shop_item  date_block_num        date  shop_id  item_id  item_price  \
# 0  59_22154               0  2013-01-02       59    22154       999.0
# 1  24_22154               0  2013-01-23       24    22154       999.0
# 2  27_22154               0  2013-01-20       27    22154       999.0
# 3  25_22154               0  2013-01-02       25    22154       999.0
# 4  25_22154               0  2013-01-03       25    22154       999.0
#
#    item_cnt_day  item_category_id  month  day    yr month_year
# 0           1.0                37      1    2  2013     1_2013
# 1           1.0                37      1   23  2013     1_2013
# 2           1.0                37      1   20  2013     1_2013
# 3           1.0                37      1    2  2013     1_2013
# 4           1.0                37      1    3  2013     1_2013

# %%
df_merge = pd.merge(df_test, df1,how='left',on='shop_item')

# %%
df_merge.isnull().sum()
# Out:
# shop_id_x                0
# item_id_x                0
# shop_item                0
# date_block_num      102796
# date                102796
# shop_id_y           102796
# item_id_y           102796
# item_price          102796
# item_cnt_day        102796
# item_category_id    102796
# month               102796
# day                 102796
# yr                  102796
# month_year          102796
# dtype: int64

# %%
df_merge.columns
# Out:
# Index([u'shop_id_x', u'item_id_x', u'shop_item', u'date_block_num', u'date',
#        u'shop_id_y', u'item_id_y', u'item_price', u'item_cnt_day',
#        u'item_category_id', u'month', u'day', u'yr', u'month_year'],
#       dtype='object')

# %%
df_test.shape
# Out:
# (214200, 3)

# %%
df_merge[np.isnan(df_merge.month)]
# Out:
#          shop_id_x  item_id_x shop_item  date_block_num date  shop_id_y  \
# 13               5       5320    5_5320             NaN  NaN        NaN
# 24               5       5268    5_5268             NaN  NaN        NaN
# 96               5       5003    5_5003             NaN  NaN        NaN
# 342              5       4874    5_4874             NaN  NaN        NaN
# 414              5       5002    5_5002             NaN  NaN        NaN
# 523              5       5907    5_5907             NaN  NaN        NaN
# 524              5       5908    5_5908             NaN  NaN        NaN
# 604              5       5668    5_5668             NaN  NaN        NaN
# 1014             5       5826    5_5826             NaN  NaN        NaN
# 1355             5       3538    5_3538             NaN  NaN        NaN
# 1356             5       3571    5_3571             NaN  NaN        NaN
# 1404             5       3604    5_3604             NaN  NaN        NaN
# ...

# %%
df_test.shape
# Out:
# (214200, 3)

# %%
102796 / 214200.
# Out:
# 0.479906629318394

# %%
df_test.head()
# Out:
#     shop_id  item_id shop_item
# ID
# 0         5     5037    5_5037
# 1         5     5320    5_5320
# 2         5     5233    5_5233
# 3         5     5232    5_5232
# 4         5     5268    5_5268
